# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # LOADING THE DATASET

# %%
df = pd.read_csv("/content/drive/MyDrive/VBD-data+code/climate_withcases.csv")

# %%
df.head(4)
# Out:
#      YEAR     MONTH  MAX TEMP (deg F)  AVG TEMP  MIN TEMP  DEW POINT (deg F)  \
# 0  2010.0   January             84.19     77.32     70.94              69.86
# 1  2010.0  February             86.82     79.36     71.86              70.66
# 2  2010.0     March             93.26     84.19     75.87              74.09
# 3  2010.0     April             95.36     88.28     79.64              78.24
#
#    PRECIPITATION (in)  # RAINY DAYS   WIND (mph)  HUMIDITY (%)  \
# 0                41.7            3.0        5.49          78.9
# 1                 0.0            0.0        5.72          76.3
# 2                 1.3            0.0        7.06          73.9
# 3                 1.1            0.0        9.71          73.0
#
#    Number of Cases
# 0               13
# 1                6
# 2                3
# 3                3

# %%
df.shape
# Out:
# (156, 11)

# %%
df.describe()
# Out:
#               YEAR  MAX TEMP (deg F)    AVG TEMP    MIN TEMP  \
# count   154.000000        154.000000  154.000000  154.000000
# mean   2015.922078         92.166558   84.225519   77.133052
# std       3.714540          4.904387    4.132798    4.146837
# min    2010.000000         82.260000   76.620000   67.900000
# 25%    2013.000000         88.007500   80.270000   73.997500
# 50%    2016.000000         92.385000   84.760000   77.685000
# 75%    2019.000000         95.685000   87.090000   80.275000
# max    2022.000000        103.630000   92.710000   85.870000
#
#        DEW POINT (deg F)  PRECIPITATION (in)  # RAINY DAYS   WIND (mph)  \
# count         154.000000          153.000000     153.000000  154.000000
# mean           73.853182          146.457908       4.732026    6.987727
# std             3.089521          182.537127       5.105475    1.564237
# min            66.030000            0.000000       0.000000    4.110000
# 25%            72.137500           18.140000       1.000000    5.742500
# 50%            74.190000           79.900000       3.000000    6.820000
# 75%            76.065000          222.600000       7.000000    8.267500
# max            80.780000         1040.050000      20.000000   10.450000
#
#        HUMIDITY (%)  Number of Cases
# count    154.000000       156.000000
# mean      72.787662        15.108974
# std        6.634071        10.152752
# min       53.900000         0.000000
# 25%       68.750000         6.000000
# 50%       72.800000        14.000000
# 75%       77.375000        23.250000
# max       89.000000        38.000000

# %% [markdown]
# # ANALYSING THE DATA - also, CLEANING

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
df=df.drop(["MONTH","YEAR"],axis=1)

# %%
df.head()
# Out:
#    MAX TEMP (deg F)  AVG TEMP  MIN TEMP  DEW POINT (deg F)  \
# 0             84.19     77.32     70.94              69.86
# 1             86.82     79.36     71.86              70.66
# 2             93.26     84.19     75.87              74.09
# 3             95.36     88.28     79.64              78.24
# 4             98.19     88.97     81.74              78.08
#
#    PRECIPITATION (in)  # RAINY DAYS   WIND (mph)  HUMIDITY (%)  \
# 0                41.7            3.0        5.49          78.9
# 1                 0.0            0.0        5.72          76.3
# 2                 1.3            0.0        7.06          73.9
# 3                 1.1            0.0        9.71          73.0
# 4               100.2            2.0        9.56          71.8
#
#    Number of Cases
# 0               13
# 1                6
# 2                3
# 3                3
# 4                6

# %%
#sns.pairplot(df)

# %%
plt.subplots(figsize=(10,6))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# #
