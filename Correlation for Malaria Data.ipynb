# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # LOADING THE DATASET

# %%
df = pd.read_csv("/content/drive/MyDrive/VBD-data+code/only Malaria data.csv")

# %%
df.head(4)
# Out:
#      MONTH  WEEK AGE GROUP  AGE CATEGORY  MALE  FEMALE  NO OF DEATHS  \
# 0  January     1  21 to 40             3     3       2             0
# 1  January     2  21 to 40             3     2       0             1
# 2  January     3  21 to 40             3     0       0             1
# 3  January     4  50 to 80             5     3       3             1
#
#    MIN NO OF CASES  NO OF CASES
# 0                1            5
# 1                1            2
# 2                0            0
# 3                1            6

# %%
df.shape
# Out:
# (624, 9)

# %%
df.describe()
# Out:
#              WEEK  AGE CATEGORY        MALE      FEMALE  NO OF DEATHS  \
# count  624.000000    624.000000  624.000000  624.000000    624.000000
# mean     2.500000      3.459936    2.927885    0.849359      0.764423
# std      1.118931      1.440638    2.734288    1.178894      0.785472
# min      1.000000      1.000000    0.000000    0.000000      0.000000
# 25%      1.750000      2.000000    0.000000    0.000000      0.000000
# 50%      2.500000      3.000000    2.000000    0.000000      1.000000
# 75%      3.250000      5.000000    5.000000    1.000000      1.000000
# max      4.000000      5.000000   10.000000    5.000000      2.000000
#
#        MIN NO OF CASES  NO OF CASES
# count       624.000000   624.000000
# mean          1.001603     3.777244
# std           0.724484     3.456688
# min           0.000000     0.000000
# 25%           0.000000     0.000000
# 50%           1.000000     3.000000
# 75%           2.000000     6.000000
# max           2.000000    10.000000

# %% [markdown]
# # ANALYSING THE DATA - also, CLEANING

# %%
df.columns = df.columns.str.replace('MIN NO OF CASES', 'CASES_MIN')
df.columns = df.columns.str.replace('NO OF CASES', 'CASES')
df.columns = df.columns.str.replace('NO OF DEATHS', 'DEATHS')

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
df=df.drop("AGE GROUP", axis=1)

# %%
df.head()
# Out:
#       MONTH  WEEK  AGE CATEGORY  MALE  FEMALE  DEATHS  CASES_MIN  CASES
# 0   January     1             3     3       2       0          1      5
# 1   January     2             3     2       0       1          1      2
# 2   January     3             3     0       0       1          0      0
# 3   January     4             5     3       3       1          1      6
# 4  February     1             5     1       0       1          1      1

# %%
df=df.drop(["WEEK"],axis=1)

# %%
df.head()
# Out:
#       MONTH  AGE CATEGORY  MALE  FEMALE  DEATHS  CASES_MIN  CASES
# 0   January             3     3       2       0          1      5
# 1   January             3     2       0       1          1      2
# 2   January             3     0       0       1          0      0
# 3   January             5     3       3       1          1      6
# 4  February             5     1       0       1          1      1

# %%
plt.subplots(figsize=(10,6))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# #
